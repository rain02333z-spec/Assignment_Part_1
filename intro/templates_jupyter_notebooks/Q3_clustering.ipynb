# %% [markdown]
# # Clustering

# %%
# %%sql

# %%
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans, DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('../insurance.csv')

# %% [markdown]
# a) Clustering

# %%
# 仅保留需要的列 + smoker（用于统计）
use_cols = ["age", "bmi", "children", "charges"]
df = data[use_cols].dropna()

X=StandardScaler().fit_transform(df)
kmeans = KMeans(n_clusters=3, init="k-means++",random_state=42,).fit(X)

df['cluster'] = kmeans.labels_.astype(str)
centroids=kmeans.cluster_centers_
clusterSize=kmeans.labels_
pp = sns.pairplot(df[use_cols + ["cluster"]], vars=use_cols, hue="cluster", diag_kind="hist")
pp.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 12
#      10 clusterSize=kmeans.labels_
#      11 pp = sns.pairplot(df[use_cols + ["cluster"]], vars=use_cols, hue="cluster", diag_kind="hist")
# ---> 12 pp.show()
#
# AttributeError: 'PairGrid' object has no attribute 'show'
